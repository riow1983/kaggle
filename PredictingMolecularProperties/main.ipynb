# %%
# %ls
# Out:
# dipole_moments.csv*                 scalar_coupling_contributions.csv*
# dipole_moments.csv.zip              scalar_coupling_contributions.csv.zip
# magnetic_shielding_tensors.csv*     structures.csv*
# magnetic_shielding_tensors.csv.zip  structures.csv.zip
# mulliken_charges.csv*               test.csv*
# mulliken_charges.csv.zip            test.csv.zip
# potential_energy.csv*               train.csv*
# potential_energy.csv.zip            train.csv.zip
# sample_submission.csv*              trash/
# sample_submission.csv.zip           Untitled.ipynb

# %%
import pandas as pd
import numpy as np

import glob

# %%
from IPython.core.display import display

# %%
glob.glob("*.csv")
# Out:
# ['test.csv',
#  'potential_energy.csv',
#  'mulliken_charges.csv',
#  'dipole_moments.csv',
#  'sample_submission.csv',
#  'train.csv',
#  'structures.csv',
#  'magnetic_shielding_tensors.csv',
#  'scalar_coupling_contributions.csv']

# %%
res = {}
for file in glob.glob("*.csv"):
    dfname = file.split(".")[0]
    res[dfname] = pd.read_csv(file)
    print(dfname)
    display(res[dfname].tail())
    print("##############################")
# Out:
# test
#               id     molecule_name  atom_index_0  atom_index_1  type
# 2505537  7163684  dsgdb9nsd_133885            15             3  2JHC
# 2505538  7163685  dsgdb9nsd_133885            15             4  2JHC
# 2505539  7163686  dsgdb9nsd_133885            15             6  3JHC
# 2505540  7163687  dsgdb9nsd_133885            15             7  2JHC
# 2505541  7163688  dsgdb9nsd_133885            15             8  1JHC
# ##############################
# potential_energy
#           molecule_name  potential_energy
# 84998  dsgdb9nsd_133879         -364.8855
# 84999  dsgdb9nsd_133880         -384.7493
# 85000  dsgdb9nsd_133881         -400.7613
# 85001  dsgdb9nsd_133882         -400.7572
# 85002  dsgdb9nsd_133884         -364.8726
# ##############################
# mulliken_charges
#             molecule_name  atom_index  mulliken_charge
# 1533532  dsgdb9nsd_133884          13         0.087616
# 1533533  dsgdb9nsd_133884          14         0.104858
# ...
